# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
diamonds_df = pd.read_csv("/vagrant/ih_datamadpt1120_project_m2/data/diamonds_train.csv")
diamonds_df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       1.21    Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1       0.32  Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2       0.71       Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3       0.41       Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4       1.02      Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 40450   1.34      Ideal     G     VS1   62.7   57.0  10070  7.10  7.04  4.43
# 40451   2.02       Good     F     SI2   57.1   60.0  12615  8.31  8.25  4.73
# 40452   1.01      Ideal     H     SI1   62.7   56.0   5457  6.37  6.42  4.01
# 40453   0.33      Ideal     J     VS1   61.9   54.3    456  4.45  4.47  2.76
# 40454   1.24      Ideal     I     SI1   62.0   58.0   6232  6.83  6.88  4.25
#
# [40455 rows x 10 columns]

# %%
#taking a look of df

diamonds_df.head()
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   1.21    Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1   0.32  Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2   0.71       Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3   0.41       Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4   1.02      Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95

# %%
diamonds_df.shape
# Out:
# (40455, 10)

# %%
diamonds_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40455 entries, 0 to 40454
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    40455 non-null  float64
#  1   cut      40455 non-null  object
#  2   color    40455 non-null  object
#  3   clarity  40455 non-null  object
#  4   depth    40455 non-null  float64
#  5   table    40455 non-null  float64
#  6   price    40455 non-null  int64
#  7   x        40455 non-null  float64
#  8   y        40455 non-null  float64
#  9   z        40455 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 3.1+ MB

# %%
diamonds_df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  40455.000000  40455.000000  40455.000000  40455.000000  40455.000000
# mean       0.797706     61.752841     57.446133   3928.444469      5.729392
# std        0.475544      1.431725      2.233535   3992.416147      1.124453
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    945.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2397.000000      5.690000
# 75%        1.040000     62.500000     59.000000   5331.000000      6.540000
# max        4.500000     79.000000     95.000000  18823.000000     10.230000
#
#                   y             z
# count  40455.000000  40455.000000
# mean       5.732819      3.537154
# std        1.146650      0.697062
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.520000
# 75%        6.540000      4.035000
# ...

# %%
diamonds_df['cut'].unique()
# Out:
# array(['Premium', 'Very Good', 'Fair', 'Good', 'Ideal'], dtype=object)

# %%
diamonds_df['color'].unique()
# Out:
# array(['J', 'H', 'G', 'D', 'F', 'E', 'I'], dtype=object)

# %%
#Localizated rows with "0" in the df

diamonds_df.query('x== 0 or z == 0 or y == 0')
# Out:
#        carat      cut color clarity  depth  table  price     x     y    z
# 1606    1.01  Premium     F     SI2   59.2   58.0   3837  6.50  6.47  0.0
# 3945    2.02  Premium     H     VS2   62.7   53.0  18207  8.02  7.95  0.0
# 6465    0.71     Good     F     SI2   64.1   60.0   2130  0.00  0.00  0.0
# 13839   2.80     Good     G     SI2   63.8   58.0  18788  8.90  8.85  0.0
# 14815   1.07    Ideal     F     SI2   61.6   56.0   4954  0.00  6.62  0.0
# 14891   2.18  Premium     H     SI2   59.4   61.0  12631  8.49  8.45  0.0
# 16425   2.20  Premium     H     SI1   61.2   59.0  17265  8.42  8.37  0.0
# 19856   1.00  Premium     G     SI2   59.1   59.0   3142  6.55  6.48  0.0
# 21602   1.15    Ideal     G     VS2   59.2   56.0   5564  6.88  6.83  0.0
# 24795   1.10  Premium     G     SI2   63.0   59.0   3696  6.50  6.47  0.0
# 26192   2.25  Premium     H     SI2   62.8   59.0  18034  0.00  0.00  0.0
# 26978   1.01  Premium     H      I1   58.1   59.0   3167  6.66  6.60  0.0
# ...

# %%
#remove rows with 0 values 

diamonds_df.drop([1606, 3945, 6465, 13839, 14815, 14891, 16425, 19856, 21602, 24795, 26192, 
                  26978, 28029, 34423, 34504, 34601], inplace=True)

# %%
# check the minimium values
diamonds_df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  40439.000000  40439.000000  40439.000000  40439.000000  40439.000000
# mean       0.797425     61.753013     57.445543   3926.535448      5.729616
# std        0.475257      1.431306      2.233055   3990.024501      1.122384
# min        0.200000     43.000000     43.000000    326.000000      3.770000
# 25%        0.400000     61.000000     56.000000    945.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2396.000000      5.690000
# 75%        1.040000     62.500000     59.000000   5329.500000      6.540000
# max        4.500000     79.000000     95.000000  18823.000000     10.230000
#
#                   y             z
# count  40439.000000  40439.000000
# mean       5.732897      3.538553
# std        1.145002      0.693639
# min        3.720000      1.070000
# 25%        4.720000      2.910000
# 50%        5.710000      3.520000
# 75%        6.540000      4.040000
# ...

# %%
# plot to find outliers

fig, ax = plt.subplots(1,2, figsize=(10, 5))
sns.boxplot(y=diamonds_df.y, ax=ax[0])
sns.boxplot(y=diamonds_df.z, ax=ax[1])
plt.subplots_adjust(wspace=0.5)

# %%
diamonds_df.loc[diamonds_df.y > 50]
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 14708    2.0  Premium     H     SI2   58.9   57.0  12210  8.09  58.9  8.06

# %%
diamonds_df.loc[diamonds_df.z > 7]
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 14708    2.0  Premium     H     SI2   58.9   57.0  12210  8.09  58.9  8.06

# %%
#remove outliers to get better results

diamonds_df.drop(14708, inplace=True)

# %%
fig, ax = plt.subplots(1,2, figsize=(10, 5))
sns.boxplot(y=diamonds_df.y, ax=ax[0])
sns.boxplot(y=diamonds_df.z, ax=ax[1])
plt.subplots_adjust(wspace=0.5)

# %%
diamonds_df.isna().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
diamonds_df.to_csv("diamonds_clean.csv")

# %%
#find colors of our dataset

diamonds_df["color"].unique()
# Out:
# array(['J', 'H', 'G', 'D', 'F', 'E', 'I'], dtype=object)

# %%
diamonds_df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       1.21    Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1       0.32  Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2       0.71       Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3       0.41       Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4       1.02      Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 40450   1.34      Ideal     G     VS1   62.7   57.0  10070  7.10  7.04  4.43
# 40451   2.02       Good     F     SI2   57.1   60.0  12615  8.31  8.25  4.73
# 40452   1.01      Ideal     H     SI1   62.7   56.0   5457  6.37  6.42  4.01
# 40453   0.33      Ideal     J     VS1   61.9   54.3    456  4.45  4.47  2.76
# 40454   1.24      Ideal     I     SI1   62.0   58.0   6232  6.83  6.88  4.25
#
# [40438 rows x 10 columns]

# %%
sns.pairplot(diamonds_df)
plt.show()

# %%
sns.scatterplot(data=diamonds_df, x=diamonds_df['y'], y=diamonds_df['carat'])
# Out:
# <AxesSubplot:xlabel='y', ylabel='carat'>

# %%
sns.scatterplot(data=diamonds_df, x=diamonds_df['x'], y=diamonds_df['carat'])
# Out:
# <AxesSubplot:xlabel='x', ylabel='carat'>

# %%
sns.scatterplot(data=diamonds_df, x=diamonds_df['z'], y=diamonds_df['carat'])
# Out:
# <AxesSubplot:xlabel='z', ylabel='carat'>

# %%
diamonds_df['cut'].value_counts()
# Out:
# Ideal        16218
# Premium      10250
# Very Good     9095
# Good          3659
# Fair          1216
# Name: cut, dtype: int64

# %%
sns.catplot('clarity', data=diamonds_df, kind='count',aspect=2.5)
# Out:
# /home/vagrant/miniconda3/envs/ironhack_env/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.scatterplot(data=diamonds_df, x=diamonds_df['carat'], y=diamonds_df['price'])
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
#scaling all features

sns.factorplot(data=diamonds_df , kind='box' , size=7, aspect=2.0)
# Out:
# /home/vagrant/miniconda3/envs/ironhack_env/lib/python3.8/site-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /home/vagrant/miniconda3/envs/ironhack_env/lib/python3.8/site-packages/seaborn/categorical.py:3720: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Correlation Between Features

corr = diamonds_df.corr()
sns.heatmap(data=corr, square=True, annot=True, cbar=True)
# Out:
# <AxesSubplot:>

# %%
sns.kdeplot(diamonds_df['carat'], shade=True , color='g')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='Density'>

# %%
sns.jointplot(x='carat' , y='price' , data=diamonds_df , hue="cut", size=10)
# Out:
# /home/vagrant/miniconda3/envs/ironhack_env/lib/python3.8/site-packages/seaborn/axisgrid.py:2073: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.factorplot(x='cut', data=diamonds_df , kind='count',aspect=2.5 )
# Out:
# /home/vagrant/miniconda3/envs/ironhack_env/lib/python3.8/site-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
#cut vs price

sns.factorplot(x='cut', y='price', data=diamonds_df, kind='box' ,aspect=3 )
# Out:
# /home/vagrant/miniconda3/envs/ironhack_env/lib/python3.8/site-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
#Color

sns.factorplot(x='color', data=diamonds_df , kind='count',aspect=2.5 )
# Out:
# /home/vagrant/miniconda3/envs/ironhack_env/lib/python3.8/site-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
#color vs price

sns.factorplot(x='color', y='price' , data=diamonds_df , kind='violin', aspect=2.5)
# Out:
# /home/vagrant/miniconda3/envs/ironhack_env/lib/python3.8/site-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
# Out:
# array(['J', 'H', 'G', 'D', 'F', 'E', 'I'], dtype=object)

# %%
sns.boxplot(x='clarity', y='price', data=diamonds_df )
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='price'>

# %%
#Depth

plt.hist('depth' , data=diamonds_df , bins=20)
# Out:
# (array([3.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 4.000e+00,
#         2.400e+01, 1.730e+02, 1.496e+03, 7.583e+03, 2.340e+04, 6.841e+03,
#         6.890e+02, 1.550e+02, 5.000e+01, 1.500e+01, 3.000e+00, 1.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([43. , 44.8, 46.6, 48.4, 50.2, 52. , 53.8, 55.6, 57.4, 59.2, 61. ,
#         62.8, 64.6, 66.4, 68.2, 70. , 71.8, 73.6, 75.4, 77.2, 79. ]),
#  <BarContainer object of 20 artists>)

# %%
#table. 

sns.kdeplot(diamonds_df['table'], shade=True , color='orange')
# Out:
# <AxesSubplot:xlabel='table', ylabel='Density'>

# %%
from scipy.stats import ttest_1samp
from scipy import stats
